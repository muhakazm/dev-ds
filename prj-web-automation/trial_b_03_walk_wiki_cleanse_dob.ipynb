# %%
import sys
import os
import importlib
import json
import pickle
import uuid
import copy
import tqdm
import requests
from urllib.parse import urlparse, unquote
from pathlib import Path

curr_path = Path.cwd()
while curr_path.name != 'tasks' and curr_path != curr_path.parent:
    curr_path = curr_path.parent

if curr_path.name == 'tasks':
    sys.path.append(str(curr_path))
else:
    raise FileNotFoundError("Could not find 'tasks' folder in parent hierarchy.")

import numpy as np
import pandas as pd

from pack import helper as h

# %%
from datetime import datetime

def convert_date_string(date_str):
    try:
        dt = datetime.strptime(date_str, "%d %B %Y")
        return dt.strftime("%Y-%m-%d")
    except:
        return None  # or raise an exception if preferred

# %%
from src import selenbeau

# %%
page_name = 'Freddie Mercury'
selenbeau.get_wiki_id_from_page_title(page_title=page_name, open_browser=True)
# Out:
# 'Q15869'

# %%
load_path = os.path.join('data', 'outputs', 'walk_wiki', 'china_people_dob.pickle')

# %%
with open(load_path, 'rb') as f:
    china_people_dob = pickle.load(f)

# %%
# remove 'gregorian'
for k,v in china_people_dob.items():
    if v and v['dob'] and 'Gregorian' in v['dob']:
        china_people_dob[k]['dob'] = china_people_dob[k]['dob'].replace('Gregorian', '')
    china_people_dob[k]['dob_formatted'] = convert_date_string(china_people_dob[k]['dob'])

# %%
pd.DataFrame(china_people_dob.values()).head(15)
# Out:
#                                                   url             page_name  \
# 0               https://en.wikipedia.org/wiki/Cao_Fei               Cao Fei
# 1   https://en.wikipedia.org/wiki/Chen_Qiang_(artist)   Chen Qiang (artist)
# 2   https://en.wikipedia.org/wiki/Michael_Lin_(art...  Michael Lin (artist)
# 3                 https://en.wikipedia.org/wiki/Li_Di                 Li Di
# 4        https://en.wikipedia.org/wiki/Zhou_Chengzhou        Zhou Chengzhou
# 5             https://en.wikipedia.org/wiki/Main_Page             Main Page
# 6           https://en.wikipedia.org/wiki/Chen_Shuxia           Chen Shuxia
# 7                https://en.wikipedia.org/wiki/Pingju                Pingju
# 8             https://en.wikipedia.org/wiki/Qiu_Deshu             Qiu Deshu
# 9        https://en.wikipedia.org/wiki/Chen_Shaoxiong        Chen Shaoxiong
# 10         https://en.wikipedia.org/wiki/Shen_Shaomin          Shen Shaomin
# 11            https://en.wikipedia.org/wiki/Ying_Miao             Ying Miao
# 12      https://en.wikipedia.org/wiki/Cao_Yu_(artist)       Cao Yu (artist)
# 13           https://en.wikipedia.org/wiki/Xiang_Jing            Xiang Jing
# 14          https://en.wikipedia.org/wiki/Xin_Fengxia           Xin Fengxia
#
#                       page_id               dob dob_formatted
# 0                    Q1034078              1978          None
# 1   No matching records found              None          None
# 2   No matching records found              None          None
# 3                   Q27527265  15 December 1999    1999-12-15
# 4                  Q105721640  28 December 1982    1982-12-28
# 5   No matching records found              None          None
# 6                   Q64740279              1963          None
# 7                     Q834885              None          None
# 8                   Q22247739              1948          None
# 9                   Q27983350              1962          None
# 10                   Q7494128              1956          None
# 11                  Q28935153              1985          None
# 12  No matching records found              None          None
# 13                  Q14480934              None          None
# 14                   Q8263391   26 January 1927    1927-01-26

# %%
china_people_dob_cleansed = [bundle for bundle in list(china_people_dob.values()) if bundle['dob_formatted'] is not None]

# %%
pd.DataFrame(china_people_dob_cleansed).head(15)
# Out:
#                                                 url         page_name  \
# 0               https://en.wikipedia.org/wiki/Li_Di             Li Di
# 1      https://en.wikipedia.org/wiki/Zhou_Chengzhou    Zhou Chengzhou
# 2         https://en.wikipedia.org/wiki/Xin_Fengxia       Xin Fengxia
# 3        https://en.wikipedia.org/wiki/He_Xiangning      He Xiangning
# 4        https://en.wikipedia.org/wiki/Li_Chevalier      Li Chevalier
# 5    https://en.wikipedia.org/wiki/Chow_Chung-cheng  Chow Chung-cheng
# 6          https://en.wikipedia.org/wiki/Chen_Guang        Chen Guang
# 7        https://en.wikipedia.org/wiki/Wang_Jianwei      Wang Jianwei
# 8               https://en.wikipedia.org/wiki/Zimei             Zimei
# 9          https://en.wikipedia.org/wiki/Gao_Minglu        Gao Minglu
# 10  https://en.wikipedia.org/wiki/Chang_Ch%27ung-ho   Chang Ch'ung-ho
# 11        https://en.wikipedia.org/wiki/Chen_Peiqiu       Chen Peiqiu
# 12           https://en.wikipedia.org/wiki/Chen_Man          Chen Man
# 13          https://en.wikipedia.org/wiki/Ai_Weiwei         Ai Weiwei
# 14   https://en.wikipedia.org/wiki/Chien-Ying_Chang  Chien-Ying Chang
#
#        page_id               dob dob_formatted
# 0    Q27527265  15 December 1999    1999-12-15
# 1   Q105721640  28 December 1982    1982-12-28
# 2     Q8263391   26 January 1927    1927-01-26
# 3     Q8248830      27 June 1878    1878-06-27
# 4     Q3237543     30 March 1961    1961-03-30
# 5    Q18019061      20 June 1908    1908-06-20
# 6    Q16727970   3 February 1995    1995-02-03
# 7    Q16269579   28 October 1958    1958-10-28
# 8     Q8072113   16 January 1971    1971-01-16
# 9    Q34224406   29 October 1949    1949-10-29
# 10    Q8463086       17 May 1914    1914-05-17
# 11   Q23683548  29 December 1922    1922-12-29
# 12   Q16203170       3 June 1980    1980-06-03
# 13     Q160115    28 August 1957    1957-08-28
# 14   Q16239462       25 May 1913    1913-05-25

# %%
import requests

def get_wiki_url_from_id(wiki_id):
    bridge_json_url = f'https://www.wikidata.org/wiki/Special:EntityData/{wiki_id}.json'
    response = requests.get(bridge_json_url)
    if response.status_code == 200:
        try:
            data = response.json()
            url = data['entities'][wiki_id]['sitelinks']['enwiki']['url']
            return url
        except:
            return None
    else:
        return None

# %%
### view
get_wiki_url_from_id('Q472683')
# Out:
# 'https://en.wikipedia.org/wiki/Nie_Haisheng'

# %%
from src import special

# %%
importlib.reload(special)
# Out:
# <module 'src.special' from 'C:\\Users\\uthop\\notebooks\\tasks\\250623_WikiLists\\src\\special.py'>

# %%
for bundle in tqdm.tqdm(china_people_dob_cleansed):
    dob_formatted = bundle['dob_formatted']
    # if 'url_checked' in bundle: continue
    is_above_50s = special.get_ymd_and_above_1950(dob_formatted)
    page_id = bundle['page_id']
    url = get_wiki_url_from_id(page_id)
    bundle['url_checked'] = url
    bundle['is_above_50s'] = is_above_50s
    bundle['name_from_url'] = special.get_name_from_link(bundle['url_checked'])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 206/206 [01:48<00:00,  1.90it/s]

# %%
china_people_dob_cleansed_df = pd.DataFrame(china_people_dob_cleansed)

# %%
### view
china_people_dob_cleansed_df.tail(15)
# Out:
#                                               url       page_name    page_id  \
# 191    https://en.wikipedia.org/wiki/Wu_Shanzhuan    Wu Shanzhuan   Q8038961
# 192         https://en.wikipedia.org/wiki/He_Rong         He Rong  Q30950291
# 193      https://en.wikipedia.org/wiki/Chen_Yixin      Chen Yixin  Q18977835
# 194  https://en.wikipedia.org/wiki/Zhuang_Rongwen  Zhuang Rongwen  Q55694631
# 195     https://en.wikipedia.org/wiki/Peng_Liyuan     Peng Liyuan    Q430911
# 196        https://en.wikipedia.org/wiki/Li_Qiang        Li Qiang  Q11097097
# 197       https://en.wikipedia.org/wiki/Li_Shulei       Li Shulei  Q15931195
# 198       https://en.wikipedia.org/wiki/He_Lifeng       He Lifeng   Q8291839
# 199    https://en.wikipedia.org/wiki/Wu_Zhenglong    Wu Zhenglong  Q10919528
# 200       https://en.wikipedia.org/wiki/Li_Ganjie       Li Ganjie  Q16076530
# 201     https://en.wikipedia.org/wiki/Wang_Huning     Wang Huning     Q64543
# 202   https://en.wikipedia.org/wiki/Ding_Xuexiang   Ding Xuexiang   Q8292421
# 203       https://en.wikipedia.org/wiki/Zhao_Leji       Zhao Leji    Q127295
# 204   https://en.wikipedia.org/wiki/Wang_Xiaohong   Wang Xiaohong  Q18109475
# 205          https://en.wikipedia.org/wiki/Cai_Qi          Cai Qi   Q3370201
#
#                    dob dob_formatted  \
# 191    25 October 1960    1960-10-25
# 192    21 October 1962    1962-10-21
# 193   1 September 1959    1959-09-01
# 194   22 February 1961    1961-02-22
# 195   20 November 1962    1962-11-20
# 196     1 January 1968    1968-01-01
# 197    21 January 1964    1964-01-21
# 198    4 February 1955    1955-02-04
# 199    6 November 1964    1964-11-06
# 200   11 November 1964    1964-11-11
# 201     6 October 1955    1955-10-06
# 202  13 September 1962    1962-09-13
# 203       8 March 1957    1957-03-08
# 204       11 July 1957    1957-07-11
# 205    5 December 1955    1955-12-05
#
#                                            url_checked is_above_50s  \
# 191         https://en.wikipedia.org/wiki/Wu_Shanzhuan   1960-10-25
# 192              https://en.wikipedia.org/wiki/He_Rong   1962-10-21
# 193           https://en.wikipedia.org/wiki/Chen_Yixin   1959-09-01
# 194       https://en.wikipedia.org/wiki/Zhuang_Rongwen   1961-02-22
# 195          https://en.wikipedia.org/wiki/Peng_Liyuan   1962-11-20
# 196  https://en.wikipedia.org/wiki/Li_Qiang_(screen...   1968-01-01
# 197            https://en.wikipedia.org/wiki/Li_Shulei   1964-01-21
# 198            https://en.wikipedia.org/wiki/He_Lifeng   1955-02-04
# 199         https://en.wikipedia.org/wiki/Wu_Zhenglong   1964-11-06
# 200            https://en.wikipedia.org/wiki/Li_Ganjie   1964-11-11
# 201          https://en.wikipedia.org/wiki/Wang_Huning   1955-10-06
# 202        https://en.wikipedia.org/wiki/Ding_Xuexiang   1962-09-13
# 203            https://en.wikipedia.org/wiki/Zhao_Leji   1957-03-08
# 204        https://en.wikipedia.org/wiki/Wang_Xiaohong   1957-07-11
# 205               https://en.wikipedia.org/wiki/Cai_Qi   1955-12-05
#
#                name_from_url
# 191             Wu Shanzhuan
# 192                  He Rong
# 193               Chen Yixin
# 194           Zhuang Rongwen
# 195              Peng Liyuan
# 196  Li Qiang (screenwriter)
# 197                Li Shulei
# 198                He Lifeng
# 199             Wu Zhenglong
# 200                Li Ganjie
# 201              Wang Huning
# 202            Ding Xuexiang
# 203                Zhao Leji
# 204            Wang Xiaohong
# 205                   Cai Qi

# %%
save_path = os.path.join('data', 'outputs', 'walk_wiki', 'china_people_dob_cleansed.pickle')

# %%
with open(save_path, 'wb') as f:
    pickle.dump(china_people_dob_cleansed, f)

# %%
keys = ['name_from_url', 'is_above_50s', 'url_checked']
all_data = list()
for index, row_ori in china_people_dob_cleansed_df.iterrows():
    row = dict(row_ori)
    is_above_50s = row['is_above_50s']
    url_checked = row['url_checked']
    name_from_url = row['name_from_url']
    if is_above_50s is not None:
        data = h.split_dict_with_keys(row, keys, follow_my_keys_order=True)[1]
        all_data.append(data)

# %%
_path = os.path.join('data', 'outputs', 'china.xlsx')
pd.DataFrame(all_data).to_excel(_path)
