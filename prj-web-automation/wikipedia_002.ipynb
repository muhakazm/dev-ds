# %%
import os
import pickle
import importlib
import pandas as pd

# %%
china_people_dob_path = os.path.join('data', 'outputs', 'walk_wiki', 'china_people_dob.pickle')
processed_core_urls_path = os.path.join('data', 'outputs', 'walk_wiki', 'core_urls_processed.pickle')

# %%
with open(china_people_dob_path, 'rb') as f:
    china_people_dob = pickle.load(f)

china_people_dob_df = pd.DataFrame(china_people_dob.values())

# %%
china_people_dob_df[~china_people_dob_df['dob'].isna()]
# Out:
#                                               url       page_name    page_id  \
# 3        https://en.wikipedia.org/wiki/Shen_Yiqin      Shen Yiqin   Q8246915
# 21   https://en.wikipedia.org/wiki/Zhang_Shengmin  Zhang Shengmin  Q19825604
# 25         https://en.wikipedia.org/wiki/Miao_Hua        Miao Hua   Q8317097
# 37           https://en.wikipedia.org/wiki/Cai_Qi          Cai Qi   Q3370201
# 53        https://en.wikipedia.org/wiki/Ying_Yong       Ying Yong   Q9134379
# 69     https://en.wikipedia.org/wiki/Chen_Wenqing    Chen Wenqing   Q8340313
# 71      https://en.wikipedia.org/wiki/Wang_Huning     Wang Huning     Q64543
# 79    https://en.wikipedia.org/wiki/Wang_Xiaohong   Wang Xiaohong  Q18109475
# 82    https://en.wikipedia.org/wiki/Wang_Dongfeng   Wang Dongfeng  Q15936001
# 99       https://en.wikipedia.org/wiki/Chen_Yixin      Chen Yixin  Q18977835
# 106     https://en.wikipedia.org/wiki/Xia_Baolong     Xia Baolong   Q2516786
# 113   https://en.wikipedia.org/wiki/Zhang_Guoqing   Zhang Guoqing   Q8292210
# 131        https://en.wikipedia.org/wiki/Dong_Jun        Dong Jun  Q60995154
# 163       https://en.wikipedia.org/wiki/Li_Ganjie       Li Ganjie  Q16076530
# 177     https://en.wikipedia.org/wiki/Peng_Liyuan     Peng Liyuan    Q430911
# 187    https://en.wikipedia.org/wiki/Wu_Zhenglong    Wu Zhenglong  Q10919528
# 218     https://en.wikipedia.org/wiki/Shi_Taifeng     Shi Taifeng   Q8292435
# 219    https://en.wikipedia.org/wiki/Zhang_Youxia    Zhang Youxia    Q705140
# 231     https://en.wikipedia.org/wiki/Xu_Xueqiang     Xu Xueqiang  Q65062337
# 234  https://en.wikipedia.org/wiki/Zhuang_Rongwen  Zhuang Rongwen  Q55694631
# 236   https://en.wikipedia.org/wiki/Zhong_Shaojun   Zhong Shaojun  Q22098996
# 263       https://en.wikipedia.org/wiki/He_Lifeng       He Lifeng   Q8291839
# 268      https://en.wikipedia.org/wiki/Liu_Jinguo      Liu Jinguo   Q8990812
# 281      https://en.wikipedia.org/wiki/He_Weidong      He Weidong  Q28409057
# 287        https://en.wikipedia.org/wiki/Li_Qiang        Li Qiang  Q11097097
# 289   https://en.wikipedia.org/wiki/Ding_Xuexiang   Ding Xuexiang   Q8292421
# 290    https://en.wikipedia.org/wiki/Li_Hongzhong    Li Hongzhong   Q1822563
# 293      https://en.wikipedia.org/wiki/Liu_Faqing      Liu Faqing  Q60993508
# 319       https://en.wikipedia.org/wiki/Li_Shulei       Li Shulei  Q15931195
# 349         https://en.wikipedia.org/wiki/He_Rong         He Rong  Q30950291
# 369       https://en.wikipedia.org/wiki/Han_Zheng       Han Zheng     Q48405
# 392       https://en.wikipedia.org/wiki/Zhao_Leji       Zhao Leji    Q127295
# 401    https://en.wikipedia.org/wiki/Liu_Guozhong    Liu Guozhong   Q8989779
#
#                    dob
# 3        December 1959
# 21       February 1958
# 25       November 1955
# 37     5 December 1955
# 53       November 1957
# 69        January 1960
# 71      6 October 1955
# 79        11 July 1957
# 82       February 1958
# 99    1 September 1959
# 106      December 1952
# 113        August 1964
# 131               1961
# 163   11 November 1964
# 177   20 November 1962
# 187    6 November 1964
# 218     September 1956
# 219          July 1950
# 231      November 1962
# 234   22 February 1961
# 236               1968
# 263    4 February 1955
# 268         April 1955
# 281               1957
# 287     1 January 1968
# 289  13 September 1962
# 290        August 1956
# 293          June 1964
# 319    21 January 1964
# 349    21 October 1962
# 369         April 1954
# 392       8 March 1957
# 401          July 1962
