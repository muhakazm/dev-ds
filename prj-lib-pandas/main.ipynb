# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
# dictionary of column-values pairs
data = {
    'name': ['A', 'B', 'C'],
    'age': [10, 11, 12]
}
df = pd.DataFrame(data)
df
# Out:
#   name  age
# 0    A   10
# 1    B   11
# 2    C   12

# %%
# list of rows
data = [
    ['D', 13],
    ['E', 14],
    ['F', 15],
]
df = pd.DataFrame(data, columns=['name', 'age'])
df
# Out:
#   name  age
# 0    D   13
# 1    E   14
# 2    F   15
